# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 판다스 실습환경 준비하기

# %% [markdown]
# ## 아나콘다 설치하기

# %% [markdown]
# ## 판다스 실습 준비하기

# %% [markdown]
# ## 안녕\? 주피터 노트북

# %% [markdown]
# ## 파이썬 패키지 관라자 pip 알아보기

# %% [markdown]
# # Pandas 시작하기

# %% [markdown]
# ## 판다스가 왜 필요할까 ?
# - 데이터셋 : 엘셀의 sheet 를 말함.
# - 시리즈 : 엑셀 sheet 의 각 열을 말함

# %% [markdown]
# ## Dataset 불러오기

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/kirenz/datasets/refs/heads/master/gapminder.csv', sep = ',')
df[(df['pop'] >= 9000000) & (df['continent'] == 'Asia')]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# ...           ...       ...   ...      ...       ...          ...
# 1675  Yemen, Rep.      Asia  1987   52.922  11219340  1971.741538
# 1676  Yemen, Rep.      Asia  1992   55.599  13367997  1879.496673
# 1677  Yemen, Rep.      Asia  1997   58.020  15826497  2117.484526
# 1678  Yemen, Rep.      Asia  2002   60.308  18701257  2234.820827
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906
#
# [239 rows x 6 columns]

# %% [markdown]
# ## dataset 메소드 및 속성

# %% [markdown]
# ### df.columns 속성

# %%
# df.columns : column 의 열 이름을 반환함.
df.dtypes             # 각 열의 데이터가 어떤 종류인지 반환
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %% [markdown]
# ###  df.index 속성

# %%
df.index        # 행 번호를 Range 로반환
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %% [markdown]
# ### df.dtypes 속성
# - 데이터셋 각 열 데이타가 어떤 데이터형인지 반환

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %% [markdown]
# ### df.info() 메소드

# %%
# 열의 자료형과 데이터와 관련된 다양한 정보를 모두 반환.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df['pop'] >= 9000000
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1699     True
# 1700     True
# 1701     True
# 1702     True
# 1703     True
# Name: pop, Length: 1704, dtype: bool

# %%
df['year'] == 2007
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703     True
# Name: year, Length: 1704, dtype: bool

# %%
 df['lifeExp'] > 50
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699     True
# 1700     True
# 1701    False
# 1702    False
# 1703    False
# Name: lifeExp, Length: 1704, dtype: bool

# %%
df[(df['year'] == 2007 ) & (df['lifeExp'] > 50)].query('continent == "Asia"').head()
# Out:
#               country continent  year  lifeExp         pop     gdpPercap
# 95            Bahrain      Asia  2007   75.635      708573  29796.048340
# 107        Bangladesh      Asia  2007   64.062   150448339   1391.253792
# 227          Cambodia      Asia  2007   59.723    14131858   1713.778686
# 299             China      Asia  2007   72.961  1318683096   4959.114854
# 671  Hong Kong, China      Asia  2007   82.208     6980412  39724.978670

# %%
df1 = df[df['year'] == 2007]
df1
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
# [142 rows x 6 columns]

# %%
df.index[7]
# Out:
# 7

# %% [markdown]
# ## 데이터세트 데이터 추출하기

# %% [markdown]
# ### 열 column 데이터 추출하기
# - df.head()
# - df.tail()
# - df.loc[ ]
# - df.iloc[ ]

# %% [markdown]
# #### df.head(), df.tail()

# %%
# 데이터세트 앞쪽 5개행을 반환해 줌.
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# 데이터세트 마지막 5개 행을 반환해 줌.
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %% [markdown]
# #### 문자열로 열 데이터 추출하기

# %%
df['country']     # 데이터시리즈로 반환
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df[['country']]    # 데이터프레임으로 반환
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df[['country','continent']]       # 여러 열을 반환할 경우 [ ] 안에 반환하고자하는 열 이름을 ' ' 또는 " "  안에 표기해야하고, 각 열은 , 로 구분한다.
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 1699     Zimbabwe    Africa
# 1700     Zimbabwe    Africa
# 1701     Zimbabwe    Africa
# 1702     Zimbabwe    Africa
# 1703     Zimbabwe    Africa
#
# [1704 rows x 2 columns]

# %% [markdown]
# #### 점 표기법

# %%
df.country                   # df.열이름 형태로 한 열을 시리즈로 반환함
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %% [markdown]
# #### 행 데이터 추출하기

# %% [markdown]
# - gapminder data 형태 확인

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# - df dataset 데이터 형태를 보면 맨 좌측의 번호가 행 번호이면서 행 이름으로도 이용됨.

# %% [markdown]
# #### df.loc iloc 속성
# - iloc[ ] , loc[ ] 로 표기하여 [ ] 안에 행 번호를 입력하여 행을 반환

# %%
df.loc[2]
# Out:
# country      Afghanistan
# continent           Asia
# year                1962
# lifeExp           31.997
# pop             10267083
# gdpPercap      853.10071
# Name: 2, dtype: object

# %%
df.loc[2:5]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[2:5]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.loc[[0,3,5]]                    # 여러 행을 추출할 경우 [ ] 안에 반환할 행들의 번호를 입력하고 ',' 로 구분해야 함.
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360

# %%
df.loc[[3,4,5],['continent','year']]       # loc[ ] 인경우 행 또는 열의 이름으로만 데이터 추출
# Out:
#   continent  year
# 3      Asia  1967
# 4      Asia  1972
# 5      Asia  1977

# %%
df.iloc[:, 3:5]
# Out:
#       lifeExp       pop
# 0      28.801   8425333
# 1      30.332   9240934
# 2      31.997  10267083
# 3      34.020  11537966
# 4      36.088  13079460
# ...       ...       ...
# 1699   62.351   9216418
# 1700   60.377  10704340
# 1701   46.809  11404948
# 1702   39.989  11926563
# 1703   43.487  12311143
#
# [1704 rows x 2 columns]

# %%
df.iloc[:, 1:5:2]
# Out:
#      continent  lifeExp
# 0         Asia   28.801
# 1         Asia   30.332
# 2         Asia   31.997
# 3         Asia   34.020
# 4         Asia   36.088
# ...        ...      ...
# 1699    Africa   62.351
# 1700    Africa   60.377
# 1701    Africa   46.809
# 1702    Africa   39.989
# 1703    Africa   43.487
#
# [1704 rows x 2 columns]

# %% [markdown]
# #### df.iloc[ ] 속성에 행과 열을 range() 속성 이용한 데이터세트 추출

# %%
df.iloc[range(3),range(2,5,1)]
# Out:
#    year  lifeExp       pop
# 0  1952   28.801   8425333
# 1  1957   30.332   9240934
# 2  1962   31.997  10267083

# %% [markdown]
# #### 행,열을 한번에 지정하여 데이터 추출 iloc, loc 속성 이용

# %%
df.loc[:,['continent','year','country']]
# Out:
#      continent  year      country
# 0         Asia  1952  Afghanistan
# 1         Asia  1957  Afghanistan
# 2         Asia  1962  Afghanistan
# 3         Asia  1967  Afghanistan
# 4         Asia  1972  Afghanistan
# ...        ...   ...          ...
# 1699    Africa  1987     Zimbabwe
# 1700    Africa  1992     Zimbabwe
# 1701    Africa  1997     Zimbabwe
# 1702    Africa  2002     Zimbabwe
# 1703    Africa  2007     Zimbabwe
#
# [1704 rows x 3 columns]

# %%
df.iloc[:5,1:5:2]
# Out:
#   continent  lifeExp
# 0      Asia   28.801
# 1      Asia   30.332
# 2      Asia   31.997
# 3      Asia   34.020
# 4      Asia   36.088

# %% [markdown]
# ## 기초통계 계산하기

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# ### 그룹화한 데이터의 평균 구하기

# %% [markdown]
# #### 그룹화한 데이터의 평균 구하기

# %% [markdown]
# ##### 1개열 그룹화하기

# %%
# 평균 기대수명 한 열 추출
df.groupby('year')['lifeExp'].mean()     # groupby('year') year 열을 기준으로 그룹화, ['lifeExp'] 열추출. mean() 평규
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('country')[['lifeExp']].mean()
# Out:
#                       lifeExp
# country
# Afghanistan         37.478833
# Albania             68.432917
# Algeria             59.030167
# Angola              37.883500
# Argentina           69.060417
# ...                       ...
# Vietnam             57.479500
# West Bank and Gaza  60.328667
# Yemen, Rep.         46.780417
# Zambia              45.996333
# Zimbabwe            52.663167
#
# [142 rows x 1 columns]

# %% [markdown]
# #### 2개 이상 열 그룹화하기

# %%
df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %% [markdown]
# #### 그룹화한 데이터 개수 구하기

# %%
df.query('continent == "Asia"')['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# Name: country, Length: 396, dtype: object

# %% [markdown]
# # 판다스 자료구조 살펴보기

# %% [markdown]
# ## 나만의 데이터 만들기

# %% [markdown]
# ## 시리즈 다루기

# %% [markdown]
# ## 데이터프레임 다루기

# %% [markdown]
# ## 시리즈와 데이터프레임 데이터 변환하기

# %% [markdown]
# ## 데이터 저장하고 불러오기

# %% [markdown]
# # 그래프 그리기

# %% [markdown]
# ## 데이터 시각화란 ?

# %%
# 데이터 셋 예제 : Anscombe's 
# 영국의 통계학자 프랭크 앤스컴이 만든 데이터셋

# %%
anscombe = sns.load_dataset('anscombe')
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ## matplotlib 란 ?

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']
print('dataset_1\n',dataset_1)
print('dataset_2\n',dataset_2)
print('dataset_3\n',dataset_3)
print('dataset_4\n',dataset_4)
# Out:
# dataset_1
#     dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# dataset_2
#     dataset     x     y
# 11      II  10.0  9.14
# 12      II   8.0  8.14
# 13      II  13.0  8.74
# 14      II   9.0  8.77
# 15      II  11.0  9.26
# 16      II  14.0  8.10
# 17      II   6.0  6.13
# 18      II   4.0  3.10
# 19      II  12.0  9.13
# 20      II   7.0  7.26
# 21      II   5.0  4.74
# dataset_3
#     dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# dataset_4
# ...

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %% [markdown]
# ####
# . plot(x, y)        # plot x and y using default line style and color
#
# . plot(x, y, 'bo')  # plot x and y using blue circle markers
#
# . plot(y)           # plot y using x as index array 0..N-1
#
# . plot(y, 'r+')     # ditto, but with red plusses

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'r+')
# plt.plot(dataset_1['y'], 'r+')

# %% [markdown]
# ### 그림영역과 하위 그래프 이해하기

# %%
# 한번에 4개의 그래프 그리기
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes1.hist(x = dataset_1['x'], bins =5)
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# %% [markdown]
# ## matplotlib 로 그래프 그리기

# %%
# tips 데이터셋을 seaborn 라이브러리에서 불러옴.
tips = sns.load_dataset('tips')
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ### 변수가 하나인 그래프 그리기

# %% [markdown]
# #### 히스토그램

# %%
fig  = plt.figure()
axes1 = fig.add_subplot(1,1,1)

axes1.hist( x = tips['total_bill'], bins = 20)   # bins = 10 : 데이터 전체의 영역을 10개의 영역으로 구별함을 의미

axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Frequency')
plt.ylim(0,50)                         # y 축 범위를 임의로 변경

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 예제 데이터프레임 불러오기
tips = sns.load_dataset("tips")

# Figure와 Axes 객체 생성
fig, ax = plt.subplots()

# 히스토그램 그리기
ax.hist(tips['total_bill'], bins=20, edgecolor='black')

# 제목 및 레이블 설정
ax.set_title('Histogram of Total Bill')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')

# 그래프 표시
plt.show()

# %% [markdown]
# ## seaborn 으로 그래프 그리기

# %% [markdown]
# ## 판다스로 그래프 그리기

# %% [markdown]
# # 깔끔한 데이터 만들기

# %% [markdown]
# ## 깔끔한 데이터란 ?
# - 변수는 열로 나타낸다.
# - 행은 관측값을 나타내야 한다.
# - 값은 셀로 나타내야 한다.
# -

# %% [markdown]
# ## 열 이름이 값일 때

# %% [markdown]
# # 데이터 결합 분해

# %% [markdown]
# ## 데이터 묶어 분석하기
# - 관측 단위별로 데이터 표를 구성
# - 관측 단위별로 정리한 다양한 표를 결합하여 데이터셋을 만들로 분석 진행
# - 하나의 데이터 셋을 여러 부분으로 분할 관리

# %% [markdown]
# ## 데이터 연결하기
# - 데이터를 결합하는 가장 쉬운 방법은 데이터를 연결(concatenate) 하는 것.
# - 즉, 데이터세트에 행이나 열을 추가함.
# - 또는 2개 이상의 데이터셋을 연결

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 예제1
df1 = pd.read_csv('concat_1.csv')
df2 = pd.read_csv('concat_2.csv')
df3 = pd.read_csv('concat_3.csv')

# %% [markdown]
# ### 행 연결하기

# %%
# 행 방향 연결하기
row_concat = pd.concat([df1, df2, df3],axis = 0)  #df1, 2,3 을 연결함.
row_concat_r=row_concat

# %% [markdown]
# '''
# - pd.concat(
#     objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]'
#       *,
#     axis: 'Axis' =\ 0,
#     join: 'str' = 'outer',
#     ignore_index: 'bool' = F                               * ignore_index = True 인경우 열 이름이 중복되지 않도록 설정가능함.alse,
#     keys: 'Iterable[Hashable] | None' = None,
#     levels=None,
#     names: 'list[HashableT] | None' = None,
#     verify_integrity: 'bool' = False,
#     sort: 'bool' = False,
#     copy: 'bool | None' = None,
# ) -> 'DataFra
#
# HashableT는 pandas 라이브러리의 concat 함수의 타입 힌트에서 사용된 제네릭 타입 변수입니다. Hashable이라는 것은 파이썬 객체가 해시 가능(immutable) 하다는 것을 의미합니다. 해시 가능한 객체는 해시 테이블(예: 딕셔너리)의 키로 사용할 수 있습니다.
#
# HashableT의 의미는 다음과 같습니다:
#
# Hashable: 해당 객체가 해시 가능함을 나타냅니다. 즉, 객체는 변경 불가능하고, 동일한 객체는 동일한 해시 값을 갖습니다. 예를 들어, 문자열, 숫자, 튜플 등은 해시 가능 객체입니다.
#
# T: 제네릭 타입 변수(T)를 나타내며, 이는 여러 타입으로 대체될 수 있습니다.
#
# 따라서 HashableT는 해시 가능 타입 변수를 의미하며, 이는 Mapping[HashableT, Series | DataFrame] 타입 힌트에서 사용됩니다. 이는 pandas.concat 함수에서 사용하는 키가 해시 가능한 타입이어야 한다는 것을 나타냅니다.
# '''me | Series'

# %%
row_concat_r
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
row_concat.iloc[3,:]
# Out:
# A    a3
# B    b3
# C    c3
# D    d3
# Name: 3, dtype: object

# %%
# new_row_series = pd.Series(['n1','n2','n3','n4']) 추가
new_row_series = pd.Series(['n1','n2','n3','n4']) 
new_row_series
# Out:
# 0    n1
# 1    n2
# 2    n3
# 3    n4
# dtype: object

# %%
new_concat_result1 = pd.concat([row_concat_r,new_row_series])

# %%
new_concat_result1
# Out:
#      A    B    C    D    0
# 0   a0   b0   c0   d0  NaN
# 1   a1   b1   c1   d1  NaN
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3  NaN
# 0   a4   b4   c4   d4  NaN
# 1   a5   b5   c5   d5  NaN
# 2   a6   b6   c6   d6  NaN
# 3   a7   b7   c7   d7  NaN
# 0   a8   b8   c8   d8  NaN
# 1   a9   b9   c9   d9  NaN
# 2  a10  b10  c10  d10  NaN
# 3  a11  b11  c11  d11  NaN
# 0  NaN  NaN  NaN  NaN   n1
# 1  NaN  NaN  NaN  NaN   n2
# 2  NaN  NaN  NaN  NaN   n3
# 3  NaN  NaN  NaN  NaN   n4

# %%
new_row = pd.DataFrame([['u', 'v', 'w', 'x']], columns=['A', 'B', 'C', 'D'])
new_row
# Out:
#    A  B  C  D
# 0  u  v  w  x

# %%
pd.concat([new_concat_result1, new_row],axis = 0)
# Out:
#      A    B    C    D    0
# 0   a0   b0   c0   d0  NaN
# 1   a1   b1   c1   d1  NaN
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3  NaN
# 0   a4   b4   c4   d4  NaN
# 1   a5   b5   c5   d5  NaN
# 2   a6   b6   c6   d6  NaN
# 3   a7   b7   c7   d7  NaN
# 0   a8   b8   c8   d8  NaN
# 1   a9   b9   c9   d9  NaN
# 2  a10  b10  c10  d10  NaN
# 3  a11  b11  c11  d11  NaN
# 0  NaN  NaN  NaN  NaN   n1
# 1  NaN  NaN  NaN  NaN   n2
# 2  NaN  NaN  NaN  NaN   n3
# 3  NaN  NaN  NaN  NaN   n4
# 0    u    v    w    x  NaN

# %% [markdown]
# ### 인덱스나 열 이름이 다른 데이터 연결하기

# %%
df1.columns = ['A', 'B', 'C', 'D']
df2.columns = ['E', 'F','G', 'H']
df3.columns = ['A', 'C', 'F', 'H']

# %%
df1, df2, df3
# Out:
# (    A   B   C   D
#  0  a0  b0  c0  d0
#  1  a1  b1  c1  d1
#  2  a2  b2  c2  d2
#  3  a3  b3  c3  d3,
#      E   F   G   H
#  0  a4  b4  c4  d4
#  1  a5  b5  c5  d5
#  2  a6  b6  c6  d6
#  3  a7  b7  c7  d7,
#       A    C    F    H
#  0   a8   b8   c8   d8
#  1   a9   b9   c9   d9
#  2  a10  b10  c10  d10
#  3  a11  b11  c11  d11)

# %%
row_concat = pd.concat([df1, df2, df3])
row_concat
# Out:
#      A    B    C    D    E    F    G    H
# 0   a0   b0   c0   d0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1   d1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   d2  NaN  NaN  NaN  NaN
# 3   a3   b3   c3   d3  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN   a4   b4   c4   d4
# 1  NaN  NaN  NaN  NaN   a5   b5   c5   d5
# 2  NaN  NaN  NaN  NaN   a6   b6   c6   d6
# 3  NaN  NaN  NaN  NaN   a7   b7   c7   d7
# 0   a8  NaN   b8  NaN  NaN   c8  NaN   d8
# 1   a9  NaN   b9  NaN  NaN   c9  NaN   d9
# 2  a10  NaN  b10  NaN  NaN  c10  NaN  d10
# 3  a11  NaN  b11  NaN  NaN  c11  NaN  d11

# %% [markdown]
# * concat() 함수를 사용하여 데이터 연결시 row_concat  예와 같이 결측값이 발생하게 되고 NaN 으로 채우게 됨.

# %%
import pandas as pd

df6 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df7 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})
df6
result = pd.concat({'first': df6, 'second': df7})
print(result)
# Out:
#           A  B
# first  0  1  3
#        1  2  4
# second 0  5  7
#        1  6  8

# %%
# 이중 인덱스 데이터프레임의 데이터 접근 방법. 예) 첫번째 행 첫번째 열의 데이터 1 에 접근하는 방법
print(result.iloc[0,0])      # iloc[] 사용법
print(result.loc[('first',0), 'A'])
# Out:
# 1
# 1

# %%
# 데이터 프레임 연결시 필연적으로 발생되는 NaN(결측치) 이 발생하지 않도록 하기 위해서는
# 데이터 프레임의 공통되는 부분만 연결하면 됨. 따라서 다음과 같이 연결하여 공통의 행 열 만 합칠 수 있음.
print(pd.concat([df1, df3],join = 'inner') )   # join = 'inner' : 이 옵션을 넣을 경우 공통의 행 열만 합치게 됨.
print(pd.concat([df2, df3],join = 'inner') ) 
print(pd.concat([df1, df2],join = 'inner') )
# Out:
#      A    C
# 0   a0   c0
# 1   a1   c1
# 2   a2   c2
# 3   a3   c3
# 0   a8   b8
# 1   a9   b9
# 2  a10  b10
# 3  a11  b11
#      F    H
# 0   b4   d4
# 1   b5   d5
# 2   b6   d6
# 3   b7   d7
# 0   c8   d8
# 1   c9   d9
# 2  c10  d10
# 3  c11  d11
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 0, 1, 2, 3]

# %% [markdown]
# ### 인덱스가 다른 데이터 열 방향 연결하기

# %%
df1.index = [0,1,2,3]
df2.index = [4,5,6,7]
df3.index = [0,2,5,7]

df1, df2, df3
# Out:
# (    A   B   C   D
#  0  a0  b0  c0  d0
#  1  a1  b1  c1  d1
#  2  a2  b2  c2  d2
#  3  a3  b3  c3  d3,
#      E   F   G   H
#  4  a4  b4  c4  d4
#  5  a5  b5  c5  d5
#  6  a6  b6  c6  d6
#  7  a7  b7  c7  d7,
#       A    C    F    H
#  0   a8   b8   c8   d8
#  2   a9   b9   c9   d9
#  5  a10  b10  c10  d10
#  7  a11  b11  c11  d11)

# %%
# axis = 1 또는 axis = 'column' 로 데이터프레임 연결하면 데이터프레임을 열방향으로 연결하게 됨.
# 인덱스가 같은 행 끼리 연결.
col_concat = pd.concat([df1,df2,df3], axis = 'columns')
col_concat
# Out:
#      A    B    C    D    E    F    G    H    A    C    F    H
# 0   a0   b0   c0   d0  NaN  NaN  NaN  NaN   a8   b8   c8   d8
# 1   a1   b1   c1   d1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   d2  NaN  NaN  NaN  NaN   a9   b9   c9   d9
# 3   a3   b3   c3   d3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   a4   b4   c4   d4  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN   a5   b5   c5   d5  a10  b10  c10  d10
# 6  NaN  NaN  NaN  NaN   a6   b6   c6   d6  NaN  NaN  NaN  NaN
# 7  NaN  NaN  NaN  NaN   a7   b7   c7   d7  a11  b11  c11  d11

# %%
# join = 'inner' 로 연결할 경우 공통인 데이터만 연결.
pd.concat([df1, df3],axis=1, join='inner')
# Out:
#     A   B   C   D   A   C   F   H
# 0  a0  b0  c0  d0  a8  b8  c8  d8
# 2  a2  b2  c2  d2  a9  b9  c9  d9

# %% [markdown]
# ## 분할된 데이터 연결

# %% [markdown]
# ### 여러 개의 파일로 분할된 데이터 연결

# %%
from pathlib import Path

billboard_data_files=(Path(".").glob("./billboard data/billboard-*.csv"))
billboard_data_files=sorted(list(billboard_data_files))
print(billboard_data_files)
# Out:
# []

# %%
billboard01 = pd.read_csv('billboard data/billboard-01.csv')
billboard02 = pd.read_csv('billboard data/billboard-02.csv')
billboard03 = pd.read_csv('billboard data/billboard-03.csv')

billboard01
# Out:
#      year            artist                    track  time date.entered week  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08  wk1
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21  wk1
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  wk1
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  wk1
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  wk1
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  wk1
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  wk1
#
#      rating
# 0      87.0
# 1      91.0
# ...

# %%
billboard = pd.concat([billboard01,billboard02,billboard03])
billboard
# Out:
#      year            artist                    track  time date.entered week  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08  wk1
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21  wk1
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  wk3
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  wk3
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  wk3
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  wk3
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  wk3
#
#      rating
# 0      87.0
# 1      91.0
# ...

# %%
assert(billboard01.shape[0]+billboard02.shape[0]+billboard03.shape[0] == billboard.shape[0])
'''  만약 billboard01, billboard02, billboard03의 행 수의 합이 billboard의 행 수와 같다면, 
#코드는 아무런 오류 없이 통과합니다. 하지만, 만약 두 값이 다르다면, AssertionError가 발생합니다.
'''
# Out:
# '  만약 billboard01, billboard02, billboard03의 행 수의 합이 billboard의 행 수와 같다면, \n#코드는 아무런 오류 없이 통과합니다. 하지만, 만약 두 값이 다르다면, AssertionError가 발생합니다.\n'

# %% [markdown]
# #### 루프 구문으로 여러개의 파일 불러오기

# %% [markdown]
# ##### for 문으로  여러개의 파일리스트 만들기

# %%
from pathlib import Path

billboard_data_files=(Path(".").glob('./billboard data/billboard*.csv'))
# billboard_data_files = list(Path(".").glob('./billboard data/billboard*.csv'  ))
# 빈리스트 생성
list_billboard_df = []

# csv 파일명 리스트 순차적으로 읽어 billboard 파일 각각의 내용이 리스트로 확보됨.
for csv_filename in billboard_data_files:
    df = pd.read_csv(csv_filename)
    list_billboard_df.append(df)
    # print(df)

# print(len(list_billboard_df))
list_billboard_df[0]


# 빌보드자료 각각이 리스트로 분리되어 있는 내용을 하나의 파일로 합침
billboard_loop_concat = pd.concat(list_billboard_df)
billboard_loop_concat
type(billboard_loop_concat)
# Out:
# pandas.core.frame.DataFrame

# %%
len(billboard_loop_concat)
# Out:
# 2219

# %% [markdown]
# ##### 리스트 컴프리헨션으로 여러 개 파일 불러오기

# %%
billboard_data_files = Path('.').glob('billboard data/billboard*.csv')

list_billboard_df=[]
for csv_billboard_df in billboard_data_files:
    df = pd.read_csv(csv_billboard_df)
    list_billboard_df.append(df)
    
print(list_billboard_df)
len(list_billboard_df)
# Out:
# [     year            artist                    track  time date.entered week  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08  wk1
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21  wk1
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  wk1
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  wk1
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  wk1
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  wk1
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  wk1
#
#      rating
# 0      87.0
# 1      91.0
# ...

# %%
billboard_data_files= Path('.').glob('billboard data/billboard*.csv')


billboard_df = [pd.read_csv(data) for data in billboard_data_files]

    
print(billboard_df)
len(billboard_df)
# Out:
# [     year            artist                    track  time date.entered week  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08  wk1
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21  wk1
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  wk1
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  wk1
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  wk1
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  wk1
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  wk1
#
#      rating
# 0      87.0
# 1      91.0
# ...

# %%
billboard_df_concat = pd.concat(billboard_df)
billboard_df_concat
# Out:
#      year            artist                    track  time date.entered week  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08  wk1
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21  wk1
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  wk7
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  wk7
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  wk7
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  wk7
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  wk7
#
#      rating
# 0      87.0
# 1      91.0
# ...

# %% [markdown]
# ## 여러 데이터셋 병합하기

# %% [markdown]
# ### 일대일 병합

# %%
visited_subset = visited.loc[[0,2,6],:]
visited_subset
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
visited_subset["site"].value_counts()
# Out:
# site
# DR-1     1
# DR-3     1
# MSK-4    1
# Name: count, dtype: int64

# %%
o2o_merge = site.merge(visited_subset, left_on = 'name', right_on='site')
o2o_merge
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %% [markdown]
# ### 다대일 병합

# %%
m2o_merge=site.merge(visited, left_on='name', right_on='site')

# %%
m2o_merge
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-1 -49.85 -128.57    622   DR-1  1927-02-10
# 2   DR-1 -49.85 -128.57    844   DR-1  1932-03-22
# 3   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 4   DR-3 -47.15 -126.72    735   DR-3  1930-01-12
# 5   DR-3 -47.15 -126.72    751   DR-3  1930-02-26
# 6   DR-3 -47.15 -126.72    752   DR-3         NaN
# 7  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],'value': [5, 6, 7, 8]})
print(df1)
print()
print(df2)

df1.merge(df2, left_on='lkey', right_on = 'rkey')      # df1 데이터프레임을 왼쪽에 놓고 오른쪽에는 df2 데이터프레임을 병합함. 각 열의 매칭은 left_on 과 right_on 에 컬럼 이름을 적어놓으면 됨.
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5
#
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        5  foo        5
# 5  foo        5  foo        8

# %% [markdown]
# ## 데이터 정규화 하기
# - 데이터프레임안에 데이터들이 중복과 불필요한 데이터가 있을 경우 중복 또는 불필요한 데이터를 없애고 데이터프레임을 재구성하는 과정을 말함

# %% [markdown]
# # 그룹으로 묶어 연산하기

# %% [markdown]
# ## 데이터 집계하기

# %% [markdown]
# ### groupby() 메소드로 데이터 집계

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/kirenz/datasets/refs/heads/\
master/gapminder.csv', sep = ',')
df.year.unique()                   # unique() 메소드로 각 열의 고유값을 알 수 있음.
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
df.groupby('year')[['lifeExp']].mean()
# Out:
#         lifeExp
# year
# 1952  49.057620
# 1957  51.507401
# 1962  53.609249
# 1967  55.678290
# 1972  57.647386
# 1977  59.570157
# 1982  61.533197
# 1987  63.212613
# 1992  64.160338
# 1997  65.014676
# 2002  65.694923
# 2007  67.007423

# %%
# 고유값 별로 데이터의 하우값을 추출.
df.loc[ df.year == 1952,:]['lifeExp'].mean()
# Out:
# np.float64(49.057619718309866)

# %% [markdown]
# #### pandas 메소드 소개

# %% [markdown]
# - count()  np.count_nonzero()    NaN 값을 제외한 데이터 개수
# - size()                         NaN 값을 포함한 데이터 개수
# - mean()   np.mean()             평균
# - std()    np.std()              표준편차
# - min()    np.min()              최소값
# - quantile(q=0.25)
# - quantile(q=0.5)
# - quantile(q=0.75)
# - max()
# - sum()
# - var()
# - sem()
# - describe()         개수, 평균, 표준편차, 최소값, 25%, 50%, 75%, 최대값
# - first()
# - last()
# - nth()

# %%
df[:4]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
df.groupby('continent')['lifeExp'].describe()
# Out:
#            count       mean        std     min       25%      50%       75%  \
# continent
# Africa     624.0  48.865330   9.150210  23.599  42.37250  47.7920  54.41150
# Americas   300.0  64.658737   9.345088  37.579  58.41000  67.0480  71.69950
# Asia       396.0  60.064903  11.864532  28.801  51.42625  61.7915  69.50525
# Europe     360.0  71.903686   5.433178  43.585  69.57000  72.2410  75.45050
# Oceania     24.0  74.326208   3.795611  69.120  71.20500  73.6650  77.55250
#
#               max
# continent
# Africa     76.442
# Americas   80.653
# Asia       82.603
# Europe     81.757
# Oceania    81.235

# %% [markdown]
# #### pandas 메소드가 아닌 메소드로 agg()와 groupby() 메소드 조합

# %% [markdown]
# - agg() 와 aggregate() 메소드는 동일한 메소드
# 1. numpy.mean, numpy.sum 등의 메소드를 agg() 에 매개변수로 전달하여 수행 가능함.
# 2.  정의함수를 매개변수로 전달하여 수행 가능 함.

# %% [markdown]
# ##### 사용자 함수 적용 예

# %%
def my_mean(values):
    n=len(values)
    sum = 0
    for value in values:
        sum += value
    return sum / n

agg_my_mean = df.groupby('year')['lifeExp'].agg(my_mean)
agg_my_mean
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
def my_mean_diff(values, diff_value):
    n = len(values)
    sum1 = 0
    for value in values:
        sum1 += value
    mean = sum1/ n
    return (mean - diff_value)

# %%
# 모든 기대 수명의 평균 구하기
global_mean = df[['lifeExp']].mean()
#

# %%
print(global_mean)
# Out:
# lifeExp    59.474439
# dtype: float64

# %%
# diff_value = 1
# df[df['country']=="Afghanistan"][['lifeExp','pop','gdpPercap']].apply(lambda x: my_mean_diff(x, diff_value))

# %%
df[:4]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df2
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df3
# Out:
#      A    B    C    D
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
df1.index, df1.columns,df1.values
# Out:
# (RangeIndex(start=0, stop=4, step=1),
#  Index(['A', 'B', 'C', 'D'], dtype='object'),
#  array([['a0', 'b0', 'c0', 'd0'],
#         ['a1', 'b1', 'c1', 'd1'],
#         ['a2', 'b2', 'c2', 'd2'],
#         ['a3', 'b3', 'c3', 'd3']], dtype=object))
